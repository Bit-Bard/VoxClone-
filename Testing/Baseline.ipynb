# %%
#Pipeline
# Voice Sample -> Speaker Encoder -> Embededding text -> Synthesizer -> Mel Spectrogram -> Vocoder -> Generated Speech

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\dhruv\OneDrive\Documents\Desktop\Deep Learning Project\VoxClone_3\voxclone\Scripts\python.exe

# %%
import torch
import torchaudio
import librosa
import soundfile
import numpy as np

print("Torch:", torch.__version__)
print("Torchaudio:", torchaudio.__version__)
print("Librosa OK")
print("Environment ready")
# Out:
# Torch: 2.10.0+cpu
# Torchaudio: 2.10.0+cpu
# Librosa OK
# Environment ready
